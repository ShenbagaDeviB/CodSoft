# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('spam.csv',encoding='latin-1')

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
df['v1']=label_encoder.fit_transform(df['v1'])
df['v2']=label_encoder.fit_transform(df['v2'])
df['Unnamed: 2']=label_encoder.fit_transform(df['Unnamed: 2'])
df['Unnamed: 3']=label_encoder.fit_transform(df['Unnamed: 3'])
df['Unnamed: 4']=label_encoder.fit_transform(df['Unnamed: 4'])
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   int32
#  1   v2          5572 non-null   int32
#  2   Unnamed: 2  5572 non-null   int32
#  3   Unnamed: 3  5572 non-null   int32
#  4   Unnamed: 4  5572 non-null   int32
# dtypes: int32(5)
# memory usage: 109.0 KB
# None

# %%
df.isnull().sum()
# Out:
# v1            0
# v2            0
# Unnamed: 2    0
# Unnamed: 3    0
# Unnamed: 4    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.iloc[:,df.columns!='v1']
y = df.iloc[:,df.columns=='v1']

# %%
print(x)
# Out:
#         v2  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0     1079          43          10           5
# 1     3101          43          10           5
# 2     1000          43          10           5
# 3     4088          43          10           5
# 4     2757          43          10           5
# ...    ...         ...         ...         ...
# 5567  3992          43          10           5
# 5568  4560          43          10           5
# 5569  3286          43          10           5
# 5570  3901          43          10           5
# 5571  3409          43          10           5
#
# [5572 rows x 4 columns]

# %%
print(y)
# Out:
#       v1
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
# ...   ..
# 5567   1
# 5568   0
# 5569   0
# 5570   0
# 5571   0
#
# [5572 rows x 1 columns]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.3)

# %%
xtrain.head()
# Out:
#         v2  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 5098  3918          43          10           5
# 1155  3649          43          10           5
# 4183  1859          43          10           5
# 196    726          43          10           5
# 2167  4746          43          10           5

# %%
xtrain.shape
# Out:
# (3900, 4)

# %%
ytrain.head()
# Out:
#       v1
# 5098   1
# 1155   0
# 4183   0
# 196    0
# 2167   0

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(xtrain,ytrain.values.ravel())
# Out:
# LogisticRegression()

# %%
predict_output = model.predict(xtest)
print(predict_output)
# Out:
# [0 0 0 ... 0 0 0]

# %%
from sklearn.metrics import accuracy_score

# %%
acc=accuracy_score(predict_output,ytest)
print('The accuracy score for RF:',acc)
# Out:
# The accuracy score for RF: 0.875
